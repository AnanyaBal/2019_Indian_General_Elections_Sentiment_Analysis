# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
city=[]
lat=[]
lon=[]
w = 0
nmodi = []

    
 
class TwitterClient(object):
    
    
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'B5E16z5kWbcb9e2AR4gTGZ7R8'
        consumer_secret = 'IV6FEAoY3JQw8UcnHnNDF9dZ85QHXAfRVgjCEN3UZnBNhMMCm7'
        access_token = '743130141136539649-Ir84tvFG8AaASGdObKieAHP508az75x'
        access_token_secret = 'S7d7yoLEBvyiwgxQdzUMoOMqAJ8Sh23wqY5b9lYwSfleY'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            print(self.auth)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        #print(tweet)
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
        
 
        try:
            city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
            lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
            lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
            # call twitter api to fetch tweets
            
            
            for i in range(29):
               
                fetched_tweets = self.api.search(q = query, count = count, since_id="201926020000", coordinates=[lat[i], lon[i], 100])
                global w
                
                # parsing tweets one by one
                for tweet in fetched_tweets:
                    # empty dictionary to store required params of a tweet
                    parsed_tweet = {}
                    
                    
                    
                
 
                    # saving text of tweet
                    parsed_tweet['text'] = tweet.text
               
                    # saving sentiment of tweet
                    parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                    # appending parsed tweet to tweets list
                    if tweet.retweet_count > 0:
                        # if tweet has retweets, ensure that it is appended only once
                        if parsed_tweet not in tweets:
                            tweets.append(parsed_tweet)
                    else:
                        tweets.append(parsed_tweet)
 
                # return parsed tweets
                #return tweets
                ptweets = [t for t in tweets if t['sentiment'] == 'positive']
    # percentage of positive tweets
                x=(100*len(ptweets)/len(tweets))
                nmodi.append(x)
                    
                
                    
                print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
                
    # picking negative tweets from tweets
                ntweets = [t for t in tweets if t['sentiment'] == 'negative']
    # percentage of negative tweets
                y=(100*len(ntweets)/len(tweets))
                print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
                nmodi.append(y)
                   
                
    # percentage of neutral tweets
                z=(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets))
                print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
                nmodi.append(z)
                   
               
    
            
        
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))
 
def main():
    
    # creating object of TwitterClient Class
    api = TwitterClient()
    
    # calling function to get tweets
       
    tweets = api.get_tweets(query = 'Narendra Modi', count = 1000)
    #tweets = api.get_tweets(query = 'BJP', count = 1000)

    
  
 
if __name__ == "__main__":
    # calling main function
    main()
# Out:
# <tweepy.auth.OAuthHandler object at 0x000002245D507860>
# Positive tweets percentage: 20.0 %
# Negative tweets percentage: 2.857142857142857 %
# Neutral tweets percentage: 77.14285714285714 %
# Positive tweets percentage: 24.0 %
# Negative tweets percentage: 2.0 %
# Neutral tweets percentage: 74.0 %
# Positive tweets percentage: 26.153846153846153 %
# Negative tweets percentage: 1.5384615384615385 %
# Neutral tweets percentage: 72.3076923076923 %
# Positive tweets percentage: 27.160493827160494 %
# Negative tweets percentage: 1.2345679012345678 %
# Neutral tweets percentage: 71.60493827160494 %
# Positive tweets percentage: 27.551020408163264 %
# Negative tweets percentage: 1.0204081632653061 %
# Neutral tweets percentage: 71.42857142857143 %
# Positive tweets percentage: 27.678571428571427 %
# Negative tweets percentage: 0.8928571428571429 %
# Neutral tweets percentage: 71.42857142857143 %
# Positive tweets percentage: 27.77777777777778 %
# Negative tweets percentage: 0.7936507936507936 %
# Neutral tweets percentage: 71.42857142857143 %
# Positive tweets percentage: 26.618705035971225 %
# Negative tweets percentage: 0.7194244604316546 %
# Neutral tweets percentage: 72.66187050359713 %
# Positive tweets percentage: 25.827814569536425 %
# Negative tweets percentage: 0.6622516556291391 %
# Neutral tweets percentage: 73.50993377483444 %
# Positive tweets percentage: 25.308641975308642 %
# Negative tweets percentage: 0.6172839506172839 %
# Neutral tweets percentage: 74.07407407407408 %
# Positive tweets percentage: 25.28735632183908 %
# Negative tweets percentage: 0.5747126436781609 %
# Neutral tweets percentage: 74.13793103448276 %
# Positive tweets percentage: 24.864864864864863 %
# Negative tweets percentage: 0.5405405405405406 %
# Neutral tweets percentage: 74.5945945945946 %
# Positive tweets percentage: 24.489795918367346 %
# Negative tweets percentage: 0.5102040816326531 %
# Neutral tweets percentage: 75.0 %
# Positive tweets percentage: 24.401913875598087 %
# Negative tweets percentage: 0.4784688995215311 %
# Neutral tweets percentage: 75.11961722488039 %
# Positive tweets percentage: 24.43438914027149 %
# Negative tweets percentage: 0.45248868778280543 %
# Neutral tweets percentage: 75.1131221719457 %
# Positive tweets percentage: 24.242424242424242 %
# Negative tweets percentage: 0.4329004329004329 %
# Neutral tweets percentage: 75.32467532467533 %
# Positive tweets percentage: 24.166666666666668 %
# Negative tweets percentage: 0.4166666666666667 %
# Neutral tweets percentage: 75.41666666666667 %
# Positive tweets percentage: 24.193548387096776 %
# Negative tweets percentage: 0.4032258064516129 %
# Neutral tweets percentage: 75.40322580645162 %
# Positive tweets percentage: 24.324324324324323 %
# Negative tweets percentage: 0.3861003861003861 %
# Neutral tweets percentage: 75.2895752895753 %
# Positive tweets percentage: 24.444444444444443 %
# Negative tweets percentage: 0.37037037037037035 %
# Neutral tweets percentage: 75.18518518518519 %
# Positive tweets percentage: 24.555160142348754 %
# Negative tweets percentage: 0.35587188612099646 %
# Neutral tweets percentage: 75.08896797153025 %
# Positive tweets percentage: 24.742268041237114 %
# Negative tweets percentage: 0.3436426116838488 %
# Neutral tweets percentage: 74.91408934707904 %
# Positive tweets percentage: 24.58471760797342 %
# Negative tweets percentage: 0.33222591362126247 %
# Neutral tweets percentage: 75.08305647840531 %
# Positive tweets percentage: 24.437299035369776 %
# Negative tweets percentage: 0.3215434083601286 %
# Neutral tweets percentage: 75.2411575562701 %
# Positive tweets percentage: 24.299065420560748 %
# Negative tweets percentage: 0.3115264797507788 %
# Neutral tweets percentage: 75.38940809968847 %
# Positive tweets percentage: 23.867069486404834 %
# Negative tweets percentage: 0.3021148036253776 %
# Neutral tweets percentage: 75.83081570996978 %
# Positive tweets percentage: 23.529411764705884 %
# Negative tweets percentage: 0.29411764705882354 %
# Neutral tweets percentage: 76.17647058823529 %
# Positive tweets percentage: 23.142857142857142 %
# Negative tweets percentage: 0.2857142857142857 %
# Neutral tweets percentage: 76.57142857142857 %
# Positive tweets percentage: 22.841225626740947 %
# Negative tweets percentage: 0.2785515320334262 %
# Neutral tweets percentage: 76.88022284122563 %

# %%
print(nmodi)
# Out:
# [20.0, 2.857142857142857, 77.14285714285714, 24.0, 2.0, 74.0, 26.153846153846153, 1.5384615384615385, 72.3076923076923, 27.160493827160494, 1.2345679012345678, 71.60493827160494, 27.551020408163264, 1.0204081632653061, 71.42857142857143, 27.678571428571427, 0.8928571428571429, 71.42857142857143, 27.77777777777778, 0.7936507936507936, 71.42857142857143, 26.618705035971225, 0.7194244604316546, 72.66187050359713, 25.827814569536425, 0.6622516556291391, 73.50993377483444, 25.308641975308642, 0.6172839506172839, 74.07407407407408, 25.28735632183908, 0.5747126436781609, 74.13793103448276, 24.864864864864863, 0.5405405405405406, 74.5945945945946, 24.489795918367346, 0.5102040816326531, 75.0, 24.401913875598087, 0.4784688995215311, 75.11961722488039, 24.43438914027149, 0.45248868778280543, 75.1131221719457, 24.242424242424242, 0.4329004329004329, 75.32467532467533, 24.166666666666668, 0.4166666666666667, 75.41666666666667, 24.193548387096776, 0.4032258064516129, 75.40322580645162, 24.324324324324323, 0.3861003861003861, 75.2895752895753, 24.444444444444443, 0.37037037037037035, 75.18518518518519, 24.555160142348754, 0.35587188612099646, 75.08896797153025, 24.742268041237114, 0.3436426116838488, 74.91408934707904, 24.58471760797342, 0.33222591362126247, 75.08305647840531, 24.437299035369776, 0.3215434083601286, 75.2411575562701, 24.299065420560748, 0.3115264797507788, 75.38940809968847, 23.867069486404834, 0.3021148036253776, 75.83081570996978, 23.529411764705884, 0.29411764705882354, 76.17647058823529, 23.142857142857142, 0.2857142857142857, 76.57142857142857, 22.841225626740947, 0.2785515320334262, 76.88022284122563]

# %%
posnamo=[]

for i in range(0,86,3):
    posnamo.append(nmodi[i])

# %%
import csv
from itertools import zip_longest

# %%
city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
           
d = [city, lat, lon, posnamo]
export_data = zip_longest(*d, fillvalue = '')
with open('sentana1.csv', 'w', encoding="ISO-8859-1", newline='') as myfile:
      wr = csv.writer(myfile)
      wr.writerow(("City", "Lat", "Long", "Namo_pos"))
      wr.writerows(export_data)
myfile.close()

# %%
import plotly
plotly.__version__
# Out:
# '3.7.1'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('sentana1.csv')
df.head()

df['text'] = df['City'] + '<br>Positive Sentiment : ' + (df['Namo_pos']).astype(str)+'%'
limits = [(0,49),(50,3000)]
colors = ["rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = go.Scattergeo(
        locationmode = 'ISO-3',
        lon = df_sub['Long'],
        lat = df_sub['Lat'],
        text = df_sub['text'],
        marker = go.scattergeo.Marker(
            size = df_sub['Namo_pos']*50000/scale,
            color = colors[i],
            line = go.scattergeo.marker.Line(
                width=0.5, color='rgb(40,40,40)'
            ),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = go.Layout(
        title = go.layout.Title(
            text = 'India city-wise Postive sentiments for Narendra Modi post 26th Feb airstrikes'
        ),
        showlegend = True,
        geo = go.layout.Geo(
            scope = 'asia',
            projection = go.layout.geo.Projection(
                type='equirectangular'
            ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        )
    )

fig = go.Figure(data=cities, layout=layout)
py.iplot(fig, filename='d7-Modi post air strike popularity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ananyabal/17.embed" height="525px" width="100%"></iframe>

# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
city=[]
lat=[]
lon=[]
w = 0
nmodi = []

    
 
class TwitterClient(object):
    
    
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'B5E16z5kWbcb9e2AR4gTGZ7R8'
        consumer_secret = 'IV6FEAoY3JQw8UcnHnNDF9dZ85QHXAfRVgjCEN3UZnBNhMMCm7'
        access_token = '743130141136539649-Ir84tvFG8AaASGdObKieAHP508az75x'
        access_token_secret = 'S7d7yoLEBvyiwgxQdzUMoOMqAJ8Sh23wqY5b9lYwSfleY'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            print(self.auth)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        #print(tweet)
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
        
 
        try:
            city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
            lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
            lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
            # call twitter api to fetch tweets
            
            
            for i in range(29):
               
                fetched_tweets = self.api.search(q = query, count = count, since_id="201901010000,201926020000", coordinates=[lat[i], lon[i], 100])
                global w
                
                # parsing tweets one by one
                for tweet in fetched_tweets:
                    # empty dictionary to store required params of a tweet
                    parsed_tweet = {}
                    
                    
                    
                
 
                    # saving text of tweet
                    parsed_tweet['text'] = tweet.text
               
                    # saving sentiment of tweet
                    parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                    # appending parsed tweet to tweets list
                    if tweet.retweet_count > 0:
                        # if tweet has retweets, ensure that it is appended only once
                        if parsed_tweet not in tweets:
                            tweets.append(parsed_tweet)
                    else:
                        tweets.append(parsed_tweet)
 
                # return parsed tweets
                #return tweets
                ptweets = [t for t in tweets if t['sentiment'] == 'positive']
    # percentage of positive tweets
                x=(100*len(ptweets)/len(tweets))
                nmodi.append(x)
                    
                
                    
                print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
                
    # picking negative tweets from tweets
                ntweets = [t for t in tweets if t['sentiment'] == 'negative']
    # percentage of negative tweets
                y=(100*len(ntweets)/len(tweets))
                print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
                nmodi.append(y)
                   
                
    # percentage of neutral tweets
                z=(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets))
                print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
                nmodi.append(z)
                   
                
    

        
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))
 
def main():
    
    # creating object of TwitterClient Class
    api = TwitterClient()
    
    # calling function to get tweets
       
    tweets = api.get_tweets(query = 'Narendra Modi', count = 1000)
    #tweets = api.get_tweets(query = 'BJP', count = 1000)

    
  
 
if __name__ == "__main__":
    # calling main function
    main()
# Out:
# <tweepy.auth.OAuthHandler object at 0x000002245D6F87F0>
# Positive tweets percentage: 9.090909090909092 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.9090909090909 %
# Positive tweets percentage: 9.30232558139535 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.69767441860465 %
# Positive tweets percentage: 9.433962264150944 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.56603773584905 %
# Positive tweets percentage: 9.523809523809524 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.47619047619048 %
# Positive tweets percentage: 9.58904109589041 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.41095890410959 %
# Positive tweets percentage: 9.523809523809524 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.47619047619048 %
# Positive tweets percentage: 9.473684210526315 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.52631578947368 %
# Positive tweets percentage: 9.433962264150944 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.56603773584905 %
# Positive tweets percentage: 9.565217391304348 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.43478260869566 %
# Positive tweets percentage: 9.75609756097561 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 90.2439024390244 %
# Positive tweets percentage: 10.606060606060606 %
# Negative tweets percentage: 0.7575757575757576 %
# Neutral tweets percentage: 88.63636363636364 %
# Positive tweets percentage: 11.347517730496454 %
# Negative tweets percentage: 1.4184397163120568 %
# Neutral tweets percentage: 87.23404255319149 %
# Positive tweets percentage: 12.0 %
# Negative tweets percentage: 2.0 %
# Neutral tweets percentage: 86.0 %
# Positive tweets percentage: 12.578616352201259 %
# Negative tweets percentage: 2.5157232704402515 %
# Neutral tweets percentage: 84.90566037735849 %
# Positive tweets percentage: 13.017751479289942 %
# Negative tweets percentage: 2.9585798816568047 %
# Neutral tweets percentage: 84.02366863905326 %
# Positive tweets percentage: 13.333333333333334 %
# Negative tweets percentage: 3.888888888888889 %
# Neutral tweets percentage: 82.77777777777777 %
# Positive tweets percentage: 14.0625 %
# Negative tweets percentage: 4.6875 %
# Neutral tweets percentage: 81.25 %
# Positive tweets percentage: 14.356435643564357 %
# Negative tweets percentage: 5.445544554455446 %
# Neutral tweets percentage: 80.1980198019802 %
# Positive tweets percentage: 14.622641509433961 %
# Negative tweets percentage: 6.132075471698113 %
# Neutral tweets percentage: 79.24528301886792 %
# Positive tweets percentage: 14.864864864864865 %
# Negative tweets percentage: 6.756756756756757 %
# Neutral tweets percentage: 78.37837837837837 %
# Positive tweets percentage: 15.021459227467812 %
# Negative tweets percentage: 7.725321888412017 %
# Neutral tweets percentage: 77.25321888412017 %
# Positive tweets percentage: 14.814814814814815 %
# Negative tweets percentage: 8.641975308641975 %
# Neutral tweets percentage: 76.54320987654322 %
# Positive tweets percentage: 14.566929133858268 %
# Negative tweets percentage: 9.448818897637794 %
# Neutral tweets percentage: 75.98425196850394 %
# Positive tweets percentage: 14.393939393939394 %
# Negative tweets percentage: 10.227272727272727 %
# Neutral tweets percentage: 75.37878787878788 %
# Positive tweets percentage: 14.181818181818182 %
# Negative tweets percentage: 10.909090909090908 %
# Neutral tweets percentage: 74.9090909090909 %
# Positive tweets percentage: 13.937282229965156 %
# Negative tweets percentage: 11.498257839721255 %
# Neutral tweets percentage: 74.56445993031359 %
# Positive tweets percentage: 14.046822742474916 %
# Negative tweets percentage: 12.040133779264215 %
# Neutral tweets percentage: 73.91304347826087 %
# Positive tweets percentage: 14.14790996784566 %
# Negative tweets percentage: 12.540192926045016 %
# Neutral tweets percentage: 73.31189710610933 %
# Positive tweets percentage: 14.197530864197532 %
# Negative tweets percentage: 12.962962962962964 %
# Neutral tweets percentage: 72.8395061728395 %

# %%
posnamo=[]

for i in range(0,86,3):
    posnamo.append(nmodi[i])

# %%
city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
           
d = [city, lat, lon, posnamo]
export_data = zip_longest(*d, fillvalue = '')
with open('sentana2.csv', 'w', encoding="ISO-8859-1", newline='') as myfile:
      wr = csv.writer(myfile)
      wr.writerow(("City", "Lat", "Long", "Namo_pos"))
      wr.writerows(export_data)
myfile.close()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('sentana2.csv')
df.head()

df['text'] = df['City'] + '<br>Positive Sentiment : ' + (df['Namo_pos']).astype(str)+'%'
limits = [(0,49),(50,3000)]
colors = ["rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = go.Scattergeo(
        locationmode = 'ISO-3',
        lon = df_sub['Long'],
        lat = df_sub['Lat'],
        text = df_sub['text'],
        marker = go.scattergeo.Marker(
            size = df_sub['Namo_pos']*50000/scale,
            color = colors[i],
            line = go.scattergeo.marker.Line(
                width=0.5, color='rgb(40,40,40)'
            ),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = go.Layout(
        title = go.layout.Title(
            text = 'India city-wise Postive sentiments for Narendra Modi before 26th Feb airstrikes'
        ),
        showlegend = True,
        geo = go.layout.Geo(
            scope = 'asia',
            projection = go.layout.geo.Projection(
                type='equirectangular'
            ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        )
    )

fig = go.Figure(data=cities, layout=layout)
py.iplot(fig, filename='d8-Modi pre air strike popularity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ananyabal/21.embed" height="525px" width="100%"></iframe>
