# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
city=[]
lat=[]
lon=[]
w = 0
nmodi = []
rgandhi = []
bjp = []
congress = []
    
 
class TwitterClient(object):
    
    
    def __init__(self):
        
        #Class constructor or initialization method.
        
        # keys and tokens from the Twitter Developer Console
        consumer_key = 'B5E16z5kWbcb9e2AR4gTGZ7R8'
        consumer_secret = 'IV6FEAoY3JQw8UcnHnNDF9dZ85QHXAfRVgjCEN3UZnBNhMMCm7'
        access_token = '743130141136539649-Ir84tvFG8AaASGdObKieAHP508az75x'
        access_token_secret = 'S7d7yoLEBvyiwgxQdzUMoOMqAJ8Sh23wqY5b9lYwSfleY'
 
        # authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            print(self.auth)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        
        #Utility function to clean tweet text by removing links, special characters using simple regex statements.
        
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        
       #Utility function to classify sentiment of passed tweet using textblob's sentiment method
        
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        
        # assigning % using polarity
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count):
        
        # Main function to fetch tweets and parse them.
        
        # empty list to store parsed tweets
        tweets = []
        
 
        try:
            city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
            lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
            lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
            
            # call twitter api to fetch tweets
            
            for i in range(29):
               
                fetched_tweets = self.api.search(q = query, count = count, since_id="201901010000", coordinates=[lat[i], lon[i], 100])
                global w
                
                # parsing tweets one by one
                for tweet in fetched_tweets:
                    # empty dictionary to store required params of a tweet
                    parsed_tweet = {}
                                       
                                  
                    # saving text of tweet
                    parsed_tweet['text'] = tweet.text
               
                    # saving sentiment of tweet
                    parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                    # appending parsed tweet to tweets list
                    if tweet.retweet_count > 0:
                        # if tweet has retweets, ensure that it is appended only once
                        if parsed_tweet not in tweets:
                            tweets.append(parsed_tweet)
                    else:
                        tweets.append(parsed_tweet)
 
                # return parsed tweets
                #return tweets
                ptweets = [t for t in tweets if t['sentiment'] == 'positive']
    # percentage of positive tweets
                x=(100*len(ptweets)/len(tweets))
                if w < 87:
                    nmodi.append(x)
                    w+=1
                elif w >= 87 & w < 174:
                    rgandhi.append(x)
                    w+=1
                elif w >=174 & w < 261:
                    bjp.append(x)
                    w+=1
                else:
                    congress.append(x)
                    w+=1
                    
                print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
                
    # picking negative tweets from tweets
                ntweets = [t for t in tweets if t['sentiment'] == 'negative']
    # percentage of negative tweets
                y=(100*len(ntweets)/len(tweets))
                print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
                if w < 87:
                    nmodi.append(y)
                    w+=1
                elif w >= 87 & w < 174:
                    rgandhi.append(y)
                    w+=1
                elif w >=174 & w < 261:
                    bjp.append(y)
                    w+=1
                else:
                    congress.append(y)
                    w+=1
    # percentage of neutral tweets
                z=(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets))
                print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
                if w < 87:
                    nmodi.append(z)
                    w+=1
                elif w >= 87 & w < 174:
                    rgandhi.append(z)
                    w+=1
                elif w >=174 & w < 261:
                    bjp.append(z)
                    w+=1
                else:
                    congress.append(z)
                    w+=1
    # printing first 5 positive tweets
                print("\n\nPositive tweets:")
                for tweet in ptweets[:10]:
                    print(tweet['text'])
 
    # printing first 5 negative tweets
                print("\n\nNegative tweets:")
                for tweet in ntweets[:10]:
                    print(tweet['text'])
            #return tweets
                #print(w)
                
    
            
        
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))
 
def main():
    
    # creating object of TwitterClient Class
    api = TwitterClient()
    
    # calling function to get tweets
       
    tweets = api.get_tweets(query = 'Narendra Modi', count = 1000)
    tweets = api.get_tweets(query = 'Rahul Gandhi', count = 1000)
    #tweets = api.get_tweets(query = 'BJP', count = 1000)
    #tweets = api.get_tweets(query = 'INCIndia', count = 1000)
    
  
 
if __name__ == "__main__":
    # calling main function
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-fa4581a94fbe> in <module>
#       2 import tweepy
#       3 from tweepy import OAuthHandler
# ----> 4 from textblob import TextBlob
#       5 city=[]
#       6 lat=[]
#
# ~\Anaconda3\lib\site-packages\textblob\__init__.py in <module>
#       1 import os
# ----> 2 from .blob import TextBlob, Word, Sentence, Blobber, WordList
#       3
#       4 __version__ = '0.15.3'
#       5 __license__ = 'MIT'
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in <module>
#      26 from collections import defaultdict
#      27
# ---> 28 import nltk
#      29
#      30 from textblob.decorators import cached_property, requires_nltk_corpus
#
# ~\Anaconda3\lib\site-packages\nltk\__init__.py in <module>
#     135 from nltk.translate import *
#     136 from nltk.sem import *
# --> 137 from nltk.stem import *
#     138
# ...

# %%
print(nmodi)
# Out:
# [17.647058823529413, 0.0, 82.3529411764706, 18.181818181818183, 0.0, 81.81818181818181, 15.384615384615385, 0.0, 84.61538461538461, 13.333333333333334, 0.0, 86.66666666666667, 11.764705882352942, 0.0, 88.23529411764706, 10.526315789473685, 0.0, 89.47368421052632, 9.75609756097561, 0.0, 90.2439024390244, 9.090909090909092, 0.0, 90.9090909090909, 10.416666666666666, 0.0, 89.58333333333333, 11.320754716981131, 0.0, 88.67924528301887, 11.864406779661017, 0.0, 88.13559322033899, 12.307692307692308, 0.0, 87.6923076923077, 14.285714285714286, 0.0, 85.71428571428571, 14.864864864864865, 0.0, 85.13513513513513, 15.384615384615385, 0.0, 84.61538461538461, 16.867469879518072, 0.0, 83.13253012048193, 17.24137931034483, 0.0, 82.75862068965517, 17.391304347826086, 0.0, 82.6086956521739, 17.52577319587629, 0.0, 82.47422680412372, 17.647058823529413, 0.0, 82.3529411764706, 17.757009345794394, 0.0, 82.24299065420561, 18.26086956521739, 0.0, 81.73913043478261, 18.0327868852459, 0.0, 81.9672131147541, 
# ...

# %%
print(rgandhi)
# Out:
# [28.571428571428573, 10.714285714285714, 60.714285714285715, 31.645569620253166, 8.860759493670885, 59.49367088607595, 33.00970873786408, 7.766990291262136, 59.22330097087379, 33.6, 7.2, 59.2, 34.0, 7.333333333333333, 58.666666666666664, 33.91812865497076, 7.60233918128655, 58.47953216374269, 33.67875647668394, 7.772020725388601, 58.54922279792746, 33.7962962962963, 7.87037037037037, 58.333333333333336, 33.61344537815126, 7.983193277310924, 58.403361344537814, 33.07692307692308, 8.076923076923077, 58.84615384615385, 32.98245614035088, 8.421052631578947, 58.59649122807018, 32.24755700325733, 9.120521172638437, 58.63192182410423, 31.804281345565748, 9.174311926605505, 59.02140672782875, 31.60919540229885, 9.195402298850574, 59.195402298850574, 31.25, 9.23913043478261, 59.51086956521739, 30.848329048843187, 9.254498714652957, 59.897172236503856, 30.413625304136254, 9.489051094890511, 60.09732360097323, 30.09259259259259, 9.49074074074074, 60.416666666666664, 30.10989010989011, 9.4505494
# ...

# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
w = 0
bjp = []
congress = []
    
 
class TwitterClient(object):
    
    
    def __init__(self):
        
        #Class constructor or initialization method.
        
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'B5E16z5kWbcb9e2AR4gTGZ7R8'
        consumer_secret = 'IV6FEAoY3JQw8UcnHnNDF9dZ85QHXAfRVgjCEN3UZnBNhMMCm7'
        access_token = '743130141136539649-Ir84tvFG8AaASGdObKieAHP508az75x'
        access_token_secret = 'S7d7yoLEBvyiwgxQdzUMoOMqAJ8Sh23wqY5b9lYwSfleY'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            print(self.auth)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        #print(tweet)
        
        #Utility function to clean tweet text by removing links, special characters using simple regex statements.
        
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        
        #Utility function to classify sentiment of passed tweet  using textblob's sentiment method
        
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count):
        
        #Main function to fetch tweets and parse them.
        
        # empty list to store parsed tweets
        tweets = []
        
 
        try:
            city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
            lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
            lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
            # call twitter api to fetch tweets
            
            
            for i in range(29):
               
                fetched_tweets = self.api.search(q = query, count = count, since_id="201901010000", coordinates=[lat[i], lon[i], 100])
                global w
                
                # parsing tweets one by one
                for tweet in fetched_tweets:
                    # empty dictionary to store required params of a tweet
                    parsed_tweet = {}
                    
                    
                    
                
 
                    # saving text of tweet
                    parsed_tweet['text'] = tweet.text
               
                    # saving sentiment of tweet
                    parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                    # appending parsed tweet to tweets list
                    if tweet.retweet_count > 0:
                        # if tweet has retweets, ensure that it is appended only once
                        if parsed_tweet not in tweets:
                            tweets.append(parsed_tweet)
                    else:
                        tweets.append(parsed_tweet)
 
                # return parsed tweets
                #return tweets
                ptweets = [t for t in tweets if t['sentiment'] == 'positive']
    # percentage of positive tweets
                x=(100*len(ptweets)/len(tweets))
                if w < 87:
                    bjp.append(x)
                    w+=1
                elif w >= 87 & w < 174:
                    congress.append(x)
                    w+=1
                elif w >=174 & w < 261:
                    bjp.append(x)
                    w+=1
                else:
                    congress.append(x)
                    w+=1
                    
                print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
                
    # picking negative tweets from tweets
                ntweets = [t for t in tweets if t['sentiment'] == 'negative']
    # percentage of negative tweets
                y=(100*len(ntweets)/len(tweets))
                print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
                if w < 87:
                    bjp.append(y)
                    w+=1
                elif w >= 87 & w < 174:
                    congress.append(y)
                    w+=1
                elif w >=174 & w < 261:
                    bjp.append(y)
                    w+=1
                else:
                    congress.append(y)
                    w+=1
    # percentage of neutral tweets
                z=(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets))
                print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
                if w < 87:
                    bjp.append(z)
                    w+=1
                elif w >= 87 & w < 174:
                    congress.append(z)
                    w+=1
                elif w >=174 & w < 261:
                    bjp.append(z)
                    w+=1
                else:
                    congress.append(z)
                    w+=1
    # printing first 5 positive tweets
                print("\n\nPositive tweets:")
                for tweet in ptweets[:10]:
                    print(tweet['text'])
 
    # printing first 5 negative tweets
                print("\n\nNegative tweets:")
                for tweet in ntweets[:10]:
                    print(tweet['text'])
            #return tweets
                #print(w)
                
    
            
        
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))
 
def main():
    
    # creating object of TwitterClient Class
    api = TwitterClient()
    
    # calling function to get tweets
       
    #tweets = api.get_tweets(query = 'Narendra Modi', count = 1000)
    #tweets = api.get_tweets(query = 'Rahul Gandhi', count = 1000)
    tweets = api.get_tweets(query = 'BJP', count = 1000)
    tweets = api.get_tweets(query = 'INCIndia', count = 1000)
    
  
 
if __name__ == "__main__":
    # calling main function
    main()
# Out:
# ...
# Positive tweets percentage: 20.28985507246377 %
# Negative tweets percentage: 13.043478260869565 %
# Neutral tweets percentage: 66.66666666666667 %
#
#
# Positive tweets:
# New Delhi: Despite being in power for five years, most of the voters spread across the cross-section of society fee… https://t.co/mkXAW5Uicr
# RT @ANI: West Bengal: Body of a 42-year-old man was found hanging at BJP booth office in Siliguri early morning today; Police investigation…
# RT @Memeghnad: BJP can criticize Congress manifesto all it wants, call it names even, but the truth is a delay in releasing their own manif…
# RT @bainjal: Very amused the Bjp has doubled the spend on the IT cell &amp; General Modi’s army of trolls. Now individuals followed by Modi hav…
# RT @BJP4Odisha: Press Conference by Shri @ArunJaitley at BJP Central Office, New Delhi. Watch
# https://t.co/BRVHS1A2Y1
# RT @narendramodi: An iconic city, an iconic venue and record number of people to bless us!
#
# Here are pictures from Kolkata.
# ...

# %%
print(bjp)
# Out:
# [20.28985507246377, 13.043478260869565, 66.66666666666667, 22.093023255813954, 12.790697674418604, 65.11627906976744, 21.21212121212121, 14.141414141414142, 64.64646464646465, 21.73913043478261, 13.91304347826087, 64.34782608695652, 21.705426356589147, 13.953488372093023, 64.34108527131782, 21.52777777777778, 13.88888888888889, 64.58333333333333, 22.0125786163522, 13.836477987421384, 64.15094339622641, 22.285714285714285, 13.142857142857142, 64.57142857142857, 22.75132275132275, 12.16931216931217, 65.07936507936508, 23.529411764705884, 11.27450980392157, 65.19607843137256, 24.663677130044842, 11.210762331838565, 64.12556053811659, 24.583333333333332, 11.25, 64.16666666666667, 24.124513618677042, 11.284046692607005, 64.59143968871595, 24.113475177304963, 11.347517730496454, 64.53900709219859, 24.262295081967213, 11.475409836065573, 64.26229508196721, 24.085365853658537, 11.28048780487805, 64.63414634146342, 24.068767908309457, 11.174785100286533, 64.756446991404, 23.71967654986523, 11
# ...

# %%
print(congress)
# Out:
# [17.741935483870968, 8.064516129032258, 74.19354838709677, 17.77777777777778, 8.88888888888889, 73.33333333333333, 17.647058823529413, 10.084033613445378, 72.26890756302521, 17.80821917808219, 10.95890410958904, 71.23287671232876, 17.816091954022987, 11.494252873563218, 70.6896551724138, 18.09045226130653, 11.557788944723619, 70.35175879396985, 18.061674008810574, 11.894273127753303, 70.04405286343612, 18.253968253968253, 11.904761904761905, 69.84126984126983, 18.47826086956522, 11.956521739130435, 69.56521739130434, 18.666666666666668, 12.0, 69.33333333333333, 18.76923076923077, 12.0, 69.23076923076923, 18.624641833810887, 11.74785100286533, 69.62750716332378, 18.498659517426272, 11.528150134048257, 69.97319034852546, 18.09045226130653, 11.306532663316583, 70.60301507537689, 17.68867924528302, 11.084905660377359, 71.22641509433963, 17.410714285714285, 10.9375, 71.65178571428571, 17.12473572938689, 10.782241014799155, 72.09302325581395, 16.8, 10.6, 72.6, 16.539923954372625, 10.646387
# ...

# %%
for i in range(0,86,3):
    print(congress[i])
# Out:
# 17.741935483870968
# 17.77777777777778
# 17.647058823529413
# 17.80821917808219
# 17.816091954022987
# 18.09045226130653
# 18.061674008810574
# 18.253968253968253
# 18.47826086956522
# 18.666666666666668
# 18.76923076923077
# 18.624641833810887
# 18.498659517426272
# 18.09045226130653
# 17.68867924528302
# 17.410714285714285
# 17.12473572938689
# 16.8
# 16.539923954372625
# 16.2748643761302
# 16.06217616580311
# 15.676567656765677
# 15.530903328050712
# 15.396341463414634
# 15.249266862170089
# 15.134370579915135
# 14.986376021798366
# 14.888010540184453
# 14.758269720101781

# %%
posnamo=[]
posraga=[]
posbjp=[]
poscong=[]

for i in range(0,86,3):
    posnamo.append(nmodi[i])
    
for i in range(0,86,3):
    posraga.append(rgandhi[i])
    
for i in range(0,86,3):
    posbjp.append(bjp[i])

for i in range(0,86,3):
    poscong.append(congress[i])

# %%
import csv
from itertools import zip_longest

# %%
city=["Amaravati","Itanagar","Dispur","Patna","Raipur","Panaji","Gandhinagar","Chandigarh","Shimla","Srinagar","Benaluru","Thiruvananthapuram","Bhopal","Mumbai","Imphal","Shillong","Aizawl","Kohima","Bhubaneswar","Chandigarh","Jaipur","Gangtok","Chennai","Hyderabad","Agartala","Lucknow","Dehradun","Kolkata","New Dehli"]    
lat= [16.573,27.1,26.1433,25.5941,21.2514,15.4909,23.2156,30.7333,31.1048,34.0836,12.9716,8.5241,23.2599,19.076,24.817,25.5788,23.7271,25.6586,20.2961,30.7333,26.9124,27.3389,13.0827,17.385,23.8315,26.8467,30.3165,22.5726,28.7041]
lon= [80.3575,93.62,91.7898,85.1376,81.6296,73.8278,72.6369,76.7794,77.1734,74.7973,77.5946,76.9366,77.4126,72.8777,93.9368,91.8933,92.7176,94.1053,85.8245,76.7794,75.7873,88.6065,80.2707,78.4867,91.2868,80.9462,78.0322,88.3639,77.1025]
d = [city, lat, lon, posnamo, posraga, posbjp, poscong]
export_data = zip_longest(*d, fillvalue = '')
with open('sentana.csv', 'w', encoding="ISO-8859-1", newline='') as myfile:
      wr = csv.writer(myfile)
      wr.writerow(("City", "Lat", "Long", "Namo_pos", "Raga_pos", "BJP_pos","Cong_pos"))
      wr.writerows(export_data)
myfile.close()

# %%
import plotly
plotly.__version__
# Out:
# '3.7.1'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('sentana.csv')
df.head()

df['text'] = df['City'] + '<br>Positive Sentiment : ' + (df['Namo_pos']).astype(str)+'%'
limits = [(0,49),(50,3000)]
colors = ["rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = go.Scattergeo(
        locationmode = 'ISO-3',
        lon = df_sub['Long'],
        lat = df_sub['Lat'],
        text = df_sub['text'],
        marker = go.scattergeo.Marker(
            size = df_sub['Namo_pos']*50000/scale,
            color = colors[i],
            line = go.scattergeo.marker.Line(
                width=0.5, color='rgb(40,40,40)'
            ),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = go.Layout(
        title = go.layout.Title(
            text = 'India city-wise Postive sentiments for Narendra Modi'
        ),
        showlegend = True,
        geo = go.layout.Geo(
            scope = 'asia',
            projection = go.layout.geo.Projection(
                type='equirectangular'
            ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        )
    )

fig = go.Figure(data=cities, layout=layout)
py.iplot(fig, filename='d3-Modi popularity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ananyabal/11.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('sentana.csv')
df.head()

df['text'] = df['City'] + '<br>Positive Sentiment : ' + (df['BJP_pos']).astype(str)+'%'
limits = [(0,49),(50,3000)]
colors = ["rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = go.Scattergeo(
        locationmode = 'ISO-3',
        lon = df_sub['Long'],
        lat = df_sub['Lat'],
        text = df_sub['text'],
        marker = go.scattergeo.Marker(
            size = df_sub['BJP_pos']*50000/scale,
            color = colors[i],
            line = go.scattergeo.marker.Line(
                width=0.5, color='rgb(40,40,40)'
            ),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = go.Layout(
        title = go.layout.Title(
            text = 'India city-wise Postive sentiments for BJP'
        ),
        showlegend = True,
        geo = go.layout.Geo(
            scope = 'asia',
            projection = go.layout.geo.Projection(
                type='equirectangular'
            ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        )
    )

fig = go.Figure(data=cities, layout=layout)
py.iplot(fig, filename='d4- BJP popularity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ananyabal/13.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('sentana.csv')
df.head()

df['text'] = df['City'] + '<br>Positive Sentiment : ' + (df['Raga_pos']).astype(str)+'%'
limits = [(0,49),(50,3000)]
colors = ["rgb(0,133,200)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = go.Scattergeo(
        locationmode = 'ISO-3',
        lon = df_sub['Long'],
        lat = df_sub['Lat'],
        text = df_sub['text'],
        marker = go.scattergeo.Marker(
            size = df_sub['Raga_pos']*50000/scale,
            color = colors[i],
            line = go.scattergeo.marker.Line(
                width=0.5, color='rgb(40,40,40)'
            ),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = go.Layout(
        title = go.layout.Title(
            text = 'India city-wise Postive sentiments for Rahul Gandhi'
        ),
        showlegend = True,
        geo = go.layout.Geo(
            scope = 'asia',
            projection = go.layout.geo.Projection(
                type='equirectangular'
            ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        )
    )

fig = go.Figure(data=cities, layout=layout)
py.iplot(fig, filename='d5- Rahul Gandhi popularity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ananyabal/19.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv('sentana.csv')
df.head()

df['text'] = df['City'] + '<br>Positive Sentiment : ' + (df['Cong_pos']).astype(str)+'%'
limits = [(0,49),(50,3000)]
colors = ["rgb(0,133,200)","lightgrey"]
cities = []
scale = 5000

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = go.Scattergeo(
        locationmode = 'ISO-3',
        lon = df_sub['Long'],
        lat = df_sub['Lat'],
        text = df_sub['text'],
        marker = go.scattergeo.Marker(
            size = df_sub['Cong_pos']*50000/scale,
            color = colors[i],
            line = go.scattergeo.marker.Line(
                width=0.5, color='rgb(40,40,40)'
            ),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)

layout = go.Layout(
        title = go.layout.Title(
            text = 'India city-wise Postive sentiments for Congress'
        ),
        showlegend = True,
        geo = go.layout.Geo(
            scope = 'asia',
            projection = go.layout.geo.Projection(
                type='equirectangular'
            ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        )
    )

fig = go.Figure(data=cities, layout=layout)
py.iplot(fig, filename='d6- Indian National Congress popularity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ananyabal/15.embed" height="525px" width="100%"></iframe>
